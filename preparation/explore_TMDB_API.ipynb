# %%
import requests
import pandas as pd
import json
import time

# %%
API_key="b24188948d9a603274c706ed3a994d8f"
Base_url="https://api.themoviedb.org/3"

# %%
import requests

url = "https://api.themoviedb.org/3/movie/changes?page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiMjQxODg5NDhkOWE2MDMyNzRjNzA2ZWQzYTk5NGQ4ZiIsIm5iZiI6MTc0OTMyMDg4NS4xMjMwMDAxLCJzdWIiOiI2ODQ0ODRiNTVjYjI3ZmI4MjIzNDIwNDkiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.ZPHZFWIXI8Myl4ExhehIBjho9r3coR2WEsf0eP6kZ1E"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"results":[{"id":722071,"adult":false},{"id":621254,"adult":false},{"id":1601580,"adult":false},{"id":1591604,"adult":false},{"id":1603689,"adult":false},{"id":1603691,"adult":false},{"id":1603515,"adult":false},{"id":1603679,"adult":false},{"id":1577334,"adult":false},{"id":1595957,"adult":false},{"id":1602783,"adult":false},{"id":1594887,"adult":false},{"id":1485831,"adult":false},{"id":1543147,"adult":false},{"id":1499459,"adult":false},{"id":1524351,"adult":false},{"id":1551215,"adult":false},{"id":1569713,"adult":false},{"id":1571771,"adult":false},{"id":1590155,"adult":false},{"id":1594137,"adult":false},{"id":1596707,"adult":false},{"id":1597791,"adult":true},{"id":1600680,"adult":false},{"id":1602147,"adult":false},{"id":1603692,"adult":false},{"id":1602806,"adult":false},{"id":1437158,"adult":false},{"id":1583115,"adult":false},{"id":1585481,"adult":false},{"id":1603550,"adult":false},{"id":1603561,"adult":false},{"id":1603351,"adult":false},{"id":1603477,"adult":false},{"i
# ...

# %%
# url = "https://api.themoviedb.org/3/account/22062367/favorite/movies?language=en-US&page=1&sort_by=created_at.asc"

# headers = {
#     "accept": "application/json",
#     "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiMjQxODg5NDhkOWE2MDMyNzRjNzA2ZWQzYTk5NGQ4ZiIsIm5iZiI6MTc0OTMyMDg4NS4xMjMwMDAxLCJzdWIiOiI2ODQ0ODRiNTVjYjI3ZmI4MjIzNDIwNDkiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.ZPHZFWIXI8Myl4ExhehIBjho9r3coR2WEsf0eP6kZ1E"
# }

# response = requests.get(url, headers=headers)

# print(response.text)
# Out:
# {"page":1,"results":[],"total_pages":0,"total_results":0}

# %%
import requests

url = "https://api.themoviedb.org/3/trending/movie/day"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiMjQxODg5NDhkOWE2MDMyNzRjNzA2ZWQzYTk5NGQ4ZiIsIm5iZiI6MTc0OTMyMDg4NS4xMjMwMDAxLCJzdWIiOiI2ODQ0ODRiNTVjYjI3ZmI4MjIzNDIwNDkiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.ZPHZFWIXI8Myl4ExhehIBjho9r3coR2WEsf0eP6kZ1E"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/iN41Ccw4DctL8npfmYg1j5Tr1eb.jpg","id":83533,"title":"Avatar: Fire and Ash","original_title":"Avatar: Fire and Ash","overview":"In the wake of the devastating war against the RDA and the loss of their eldest son, Jake Sully and Neytiri face a new threat on Pandora: the Ash People, a violent and power-hungry Na'vi tribe led by the ruthless Varang. Jake's family must fight for their survival and the future of Pandora in a conflict that pushes them to their emotional and physical limits.","poster_path":"/g96wHxU7EnoIFwemb2RgohIXrgW.jpg","media_type":"movie","original_language":"en","genre_ids":[878,12,14],"popularity":566.0459,"release_date":"2025-12-17","video":false,"vote_average":7.348,"vote_count":633},{"adult":false,"backdrop_path":"/7nfpkR9XsQ1lBNCXSSHxGV7Dkxe.jpg","id":1084242,"title":"Zootopia 2","original_title":"Zootopia 2","overview":"After cracking the biggest case in Zootopia's history, rookie cops Judy Hopps and Nick Wil
# ...

# %%
response.text
# Out:
# '{"page":1,"results":[{"adult":false,"backdrop_path":"/iN41Ccw4DctL8npfmYg1j5Tr1eb.jpg","id":83533,"title":"Avatar: Fire and Ash","original_title":"Avatar: Fire and Ash","overview":"In the wake of the devastating war against the RDA and the loss of their eldest son, Jake Sully and Neytiri face a new threat on Pandora: the Ash People, a violent and power-hungry Na\'vi tribe led by the ruthless Varang. Jake\'s family must fight for their survival and the future of Pandora in a conflict that pushes them to their emotional and physical limits.","poster_path":"/g96wHxU7EnoIFwemb2RgohIXrgW.jpg","media_type":"movie","original_language":"en","genre_ids":[878,12,14],"popularity":566.0459,"release_date":"2025-12-17","video":false,"vote_average":7.348,"vote_count":633},{"adult":false,"backdrop_path":"/7nfpkR9XsQ1lBNCXSSHxGV7Dkxe.jpg","id":1084242,"title":"Zootopia 2","original_title":"Zootopia 2","overview":"After cracking the biggest case in Zootopia\'s history, rookie cops Judy Hopps and Nick
# ...

# %%
dic=json.loads(response.text)

# %%
len(dic)
# Out:
# 4

# %%
dic.keys()
# Out:
# dict_keys(['page', 'results', 'total_pages', 'total_results'])

# %%
dic['total_pages']
# Out:
# 500

# %%
type(dic['results'])
# Out:
# list

# %%
len(dic['results'])
# Out:
# 20

# %%
dic['results'][1]
# Out:
# {'adult': False,
#  'backdrop_path': '/7nfpkR9XsQ1lBNCXSSHxGV7Dkxe.jpg',
#  'id': 1084242,
#  'title': 'Zootopia 2',
#  'original_title': 'Zootopia 2',
#  'overview': "After cracking the biggest case in Zootopia's history, rookie cops Judy Hopps and Nick Wilde find themselves on the twisting trail of a great mystery when Gary De'Snake arrives and turns the animal metropolis upside down. To crack the case, Judy and Nick must go undercover to unexpected new parts of town, where their growing partnership is tested like never before.",
#  'poster_path': '/bjUWGw0Ao0qVWxagN3VCwBJHVo6.jpg',
#  'media_type': 'movie',
#  'original_language': 'en',
#  'genre_ids': [16, 35, 12, 10751, 9648],
#  'popularity': 340.9615,
#  'release_date': '2025-11-26',
#  'video': False,
#  'vote_average': 7.646,
#  'vote_count': 732}

# %%
response.text
# Out:
# '{"page":1,"results":[{"adult":false,"backdrop_path":"/iN41Ccw4DctL8npfmYg1j5Tr1eb.jpg","id":83533,"title":"Avatar: Fire and Ash","original_title":"Avatar: Fire and Ash","overview":"In the wake of the devastating war against the RDA and the loss of their eldest son, Jake Sully and Neytiri face a new threat on Pandora: the Ash People, a violent and power-hungry Na\'vi tribe led by the ruthless Varang. Jake\'s family must fight for their survival and the future of Pandora in a conflict that pushes them to their emotional and physical limits.","poster_path":"/g96wHxU7EnoIFwemb2RgohIXrgW.jpg","media_type":"movie","original_language":"en","genre_ids":[878,12,14],"popularity":566.0459,"release_date":"2025-12-17","video":false,"vote_average":7.348,"vote_count":633},{"adult":false,"backdrop_path":"/7nfpkR9XsQ1lBNCXSSHxGV7Dkxe.jpg","id":1084242,"title":"Zootopia 2","original_title":"Zootopia 2","overview":"After cracking the biggest case in Zootopia\'s history, rookie cops Judy Hopps and Nick
# ...

# %%
response.text
# Out:
# '{"dates":{"maximum":"2026-01-21","minimum":"2025-12-31"},"page":1,"results":[{"adult":false,"backdrop_path":"/iN41Ccw4DctL8npfmYg1j5Tr1eb.jpg","genre_ids":[878,12,14],"id":83533,"original_language":"en","original_title":"Avatar: Fire and Ash","overview":"In the wake of the devastating war against the RDA and the loss of their eldest son, Jake Sully and Neytiri face a new threat on Pandora: the Ash People, a violent and power-hungry Na\'vi tribe led by the ruthless Varang. Jake\'s family must fight for their survival and the future of Pandora in a conflict that pushes them to their emotional and physical limits.","popularity":566.0459,"poster_path":"/g96wHxU7EnoIFwemb2RgohIXrgW.jpg","release_date":"2025-12-17","title":"Avatar: Fire and Ash","video":false,"vote_average":7.3,"vote_count":627},{"adult":false,"backdrop_path":"/yCatt8lmp3oRFEcOZF8KHhsiASQ.jpg","genre_ids":[28,10752],"id":1223601,"original_language":"fi","original_title":"Sisu 2","overview":"Returning to the house where hi
# ...

# %% [markdown]
# this will give as just the trending movies but i need a variaty of movies to build a strong recomandation sys

# %%
categories = [
    "popular",
    "top_rated",
    "now_playing",
    "upcoming"
]

# %%
all_movie_ids = set()

# %%
for category in categories:
    url = f"{Base_url}/movie/{category}"
    params = {"api_key": API_key, "page": 1}

    response2 = requests.get(url, params=params)
    data = response2.json()

    for movie in data.get("results", []):
        all_movie_ids.add(movie["id"])

    print(f"Got {len(data.get('results', []))} from {category}")
# Out:
# Got 20 from popular
# Got 20 from top_rated
# Got 20 from now_playing
# Got 20 from upcoming

# %%
len(all_movie_ids)
# Out:
# 65

# %%
data.keys()
# Out:
# dict_keys(['dates', 'page', 'results', 'total_pages', 'total_results'])

# %%
len(data['results'])
# Out:
# 20

# %%
movies=response2.json()['results']

# %%
len(movies)
# Out:
# 20

# %%
movies[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3901301928.py in <cell line: 0>()
# ----> 1 movies[0]
#
# KeyError: 0

# %%
print(*[movie['original_title'] for movie in movies],sep='\n')
# Out:
# Avatar: Fire and Ash
# Sisu 2
# Eternity
# The Housemaid
# Nuremberg
# Anaconda
# Die My Love
# The SpongeBob Movie: Search for SquarePants
# Wildcat
# The Carpenter's Son
# Dreams
# Marty Supreme
# Sidelined 2: Intercepted
# Playdate
# یک تصادف ساده
# Affeksjonsverdi
# A Working Man
# David
# 어쩔수가없다
# The Lord of the Rings: The Fellowship of the Ring

# %%
movies[20]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-981080096.py in <cell line: 0>()
# ----> 1 movies[20]
#
# IndexError: list index out of range

# %%
response3=[]
for page in range(0,20):
    url = f"{Base_url}/discover/movie"
    params = {"api_key": API_key, "page": page}
    response3 += requests.get(url, params=params)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3171500262.py in <cell line: 0>()
#       3     url = f"{Base_url}/discover/movie"
#       4     params = {"api_key": API_key, "page": page}
# ----> 5     response3 += requests.get(url, params=params)
#       6
#       7
#
# TypeError: can only concatenate str (not "Response") to str

# %%
response3.text
# Out:
# '{"page":19,"results":[{"adult":false,"backdrop_path":"/n39lZOZI65VIq9qw7BpjbldN63b.jpg","genre_ids":[80,9648,53,18],"id":2118,"original_language":"en","original_title":"L.A. Confidential","overview":"Three detectives in the corrupt and brutal L.A. police force of the 1950s use differing methods to uncover a conspiracy behind the shotgun slayings of the patrons at an all-night diner.","popularity":14.7998,"poster_path":"/lWCgf5sD5FpMljjpkRhcC8pXcch.jpg","release_date":"1997-09-19","title":"L.A. Confidential","video":false,"vote_average":7.804,"vote_count":5321},{"adult":false,"backdrop_path":"/9Eo6FPq6A4aMeOe4tTmNKwUZRvM.jpg","genre_ids":[18,10751],"id":28178,"original_language":"en","original_title":"Hachi: A Dog\'s Tale","overview":"A drama based on the true story of a college professor\'s bond with the abandoned dog he takes into his home.","popularity":14.1118,"poster_path":"/lsy3aEsEfYIHdLRk4dontZ4s85h.jpg","release_date":"2009-06-08","title":"Hachi: A Dog\'s Tale","video":false
# ...

# %%
all_responses = []

for page in range(1, 151):
    url = f"{Base_url}/discover/movie"
    params = {"api_key": API_key, "page": page}

    response = requests.get(url, params=params)
    all_responses.append(response.json())  # Store each page's full data

# Then extract movies from all pages
all_movies = []
for response_data in all_responses:
    all_movies.extend(response_data.get("results", []))

# %%
len(all_movies)
# Out:
# 3000

# %%
all_movies[2070]
# Out:
# {'adult': False,
#  'backdrop_path': '/8qSsnSbgosaCROnvcOzeXyWsxIp.jpg',
#  'genre_ids': [35, 10749],
#  'id': 1212142,
#  'original_language': 'en',
#  'original_title': 'Kinda Pregnant',
#  'overview': "When Lainy's plan to settle down and start a family falls apart, she puts on a fake baby bump, tells a lie — and accidentally falls for her dream guy.",
#  'popularity': 5.813,
#  'poster_path': '/k2Lq3rCJ7P9gk5Df9of9kqr9IJM.jpg',
#  'release_date': '2025-02-04',
#  'title': 'Kinda Pregnant',
#  'video': False,
#  'vote_average': 5.6,
#  'vote_count': 290}

# %%
type(all_movies)
# Out:
# list

# %%
df=pd.DataFrame(all_movies)

# %%
df.head()
# Out:
#    adult                     backdrop_path                  genre_ids  \
# 0  False  /iN41Ccw4DctL8npfmYg1j5Tr1eb.jpg              [878, 12, 14]
# 1  False  /3jMN1k8b0Ptd9eMoeftUyDGJdCh.jpg              [878, 12, 18]
# 2  False  /7nfpkR9XsQ1lBNCXSSHxGV7Dkxe.jpg  [16, 35, 12, 10751, 9648]
# 3  False  /dHSz0tSFuO2CsXJ1CApSauP9Ncl.jpg             [53, 80, 9648]
# 4  False  /54BOXpX2ieTXMDzHymdDMnUIzYG.jpg                   [27, 53]
#
#         id original_language                 original_title  \
# 0    83533                en           Avatar: Fire and Ash
# 1   982843                ko                            대홍수
# 2  1084242                en                     Zootopia 2
# 3   425274                en  Now You See Me: Now You Don't
# 4  1228246                en      Five Nights at Freddy's 2
#
#                                             overview  popularity  \
# 0  In the wake of the devastating war against the...    566.0459
# ...

# %%
df1=df.drop(['backdrop_path','original_title','poster_path','title','video'],axis=1)

# %%
df1.head()
# Out:
#    adult                  genre_ids       id original_language  \
# 0  False              [878, 12, 14]    83533                en
# 1  False              [878, 12, 18]   982843                ko
# 2  False  [16, 35, 12, 10751, 9648]  1084242                en
# 3  False             [53, 80, 9648]   425274                en
# 4  False                   [27, 53]  1228246                en
#
#                                             overview  popularity release_date  \
# 0  In the wake of the devastating war against the...    566.0459   2025-12-17
# 1  When a raging flood traps a researcher and her...    493.8003   2025-09-18
# 2  After cracking the biggest case in Zootopia's ...    340.9615   2025-11-26
# 3  The original Four Horsemen reunite with a new ...    325.1351   2025-11-12
# 4  One year since the supernatural nightmare at F...    358.7269   2025-12-03
#
#    vote_average  vote_count
# 0         7.348         633
# 1         6.110         241
# 2         7.646         732
# ...

# %%
df1.to_csv("/content/movie.csv")

# %%
url = f"{Base_url}/discover/movie"
params = {"api_key": API_key, "page": page, "append_to_response": "keywords" }

response4= requests.get(url, params=params)

# %%
type(response4.text)
# Out:
# str

# %%
test=response4.json()['results']

# %%
test[0]
# Out:
# {'adult': False,
#  'backdrop_path': '/7JNzw1tSZZEgsBw6lu0VfO2X2Ef.jpg',
#  'genre_ids': [28, 12, 14, 878],
#  'id': 19995,
#  'original_language': 'en',
#  'original_title': 'Avatar',
#  'overview': 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.',
#  'popularity': 120.5635,
#  'poster_path': '/gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg',
#  'release_date': '2009-12-16',
#  'title': 'Avatar',
#  'video': False,
#  'vote_average': 7.597,
#  'vote_count': 33025}

# %% [markdown]
# now i well get sevrel movies ids from 100 pages from diffrente categories then i will use the ids to get the sepecific info i need to train the model

# %%
categories = [
    "popular",
    "top_rated",
    "now_playing",
    "upcoming"
]
all_movie_ids1 = set()
for category in categories:
    for page in range(1,56):
      url = f"{Base_url}/movie/{category}"
      params = {"api_key": API_key, "page": page, "append_to_response": "credits"}

      response5 = requests.get(url, params=params)
      data1 = response5.json()

      for movie in data1.get("results", []):
          all_movie_ids1.add(movie["id"])

# %%
len(all_movie_ids1)
# Out:
# 3147

# %%
url = f"{Base_url}/movie/83533	"
params = {"api_key": API_key, "append_to_response": "keywords"}
tesst=requests.get(url,params=params)

# %%
tesst
# Out:
# <Response [200]>

# %%
tesst_=tesst.json()
tesst_
# Out:
# {'adult': False,
#  'backdrop_path': '/iN41Ccw4DctL8npfmYg1j5Tr1eb.jpg',
#  'belongs_to_collection': {'id': 87096,
#   'name': 'Avatar Collection',
#   'poster_path': '/3C5brXxnBxfkeKWwA1Fh4xvy4wr.jpg',
#   'backdrop_path': '/6qkJLRCZp9Y3ovXti5tSuhH0DpO.jpg'},
#  'budget': 350000000,
#  'genres': [{'id': 878, 'name': 'Science Fiction'},
#   {'id': 12, 'name': 'Adventure'},
#   {'id': 14, 'name': 'Fantasy'}],
#  'homepage': 'https://www.avatar.com/movies/avatar-fire-and-ash',
#  'id': 83533,
#  'imdb_id': 'tt1757678',
#  'origin_country': ['US'],
#  'original_language': 'en',
#  'original_title': 'Avatar: Fire and Ash',
# ...

# %%
tesst_.get('keywords', {}).get('keywords', [])
# Out:
# [{'id': 616, 'name': 'witch'},
#  {'id': 402, 'name': 'clone'},
#  {'id': 3386, 'name': 'space war'},
#  {'id': 10148, 'name': 'tribe'},
#  {'id': 9663, 'name': 'sequel'},
#  {'id': 9951, 'name': 'alien'},
#  {'id': 12375, 'name': 'transhumanism'},
#  {'id': 18035, 'name': 'family'},
#  {'id': 195114, 'name': 'space adventure'},
#  {'id': 205734, 'name': 'family dynamics'},
#  {'id': 237104, 'name': 'rival'}]

# %%
list_of_movies=[]
for id in all_movie_ids1:
  url = f"{Base_url}/movie/{id}"
  params = {"api_key": API_key, "append_to_response": "keywords"}

  response = requests.get(url, params=params)

  if response.status_code == 200:
    data=response.json()

    keywords=[]
    all_keywords = data.get('keywords', {}).get('keywords', [])
    for j in range(0,min(5,len(all_keywords))):

    # for j in min(range(0,5),len(keywords)):
    #   if j <=len(test['keywords']['keywords']):
    #     break

      keywords.append(all_keywords[j]['name'])

      movie_data={
          'id':data['id'],
          'title':data['title'],
          'overview':data.get('overview',''),
          'genres':[g['name'] for g in data.get('genres', [])],
          'keywords':keywords,
          'adult':data.get('adult')
      }


      list_of_movies.append(movie_data)

# %%
list_of_movies[0]
# Out:
# {'id': 129,
#  'overview': 'A young girl, Chihiro, becomes trapped in a strange new world of spirits. When her parents undergo a mysterious transformation, she must call upon the courage she never knew she had to free her family.',
#  'genres': ['Animation', 'Family', 'Fantasy'],
#  'keywords': ['witch',
#   'parent child relationship',
#   'darkness',
#   'bath house',
#   'magic']}

# %%
# list_of_movies = []

# for id in all_movie_ids1:
#     url = f"{Base_url}/movie/{id}"
#     params = {"api_key": API_key, "append_to_response": "keywords"}

#     response = requests.get(url, params=params)

#     if response.status_code == 200:  # Use same variable name
#         data = response.json()

#         # Get keywords safely
#         all_keywords = data.get('keywords', {}).get('keywords', [])
#         top_keywords = []

#         for j in range(min(5, len(all_keywords))):  # Safe: up to 5
#             top_keywords.append(all_keywords[j]['name'])

#         # Create clean movie data
#         movie_data = {
#             'id': data['id'],
#             'title': data['title'],
#             'overview': data.get('overview', ''),
#             'genres': [g['name'] for g in data.get('genres', [])],
#             'keywords': top_keywords  # Clean list
#         }

#         list_of_movies.append(movie_data)


#     # time.sleep(0.1)  # IMPORTANT
# Out:
# []

# %%
y=[1,2,3,4]

# %%
for j in range(0,min(5,len(y))):
  print('test')
# Out:
# test
# test
# test
# test

# %%
len(list_of_movies)
# Out:
# 63

# %%
list_of_movies[0]['keywords']
# Out:
# {'keywords': [{'id': 616, 'name': 'witch'},
#   {'id': 970, 'name': 'parent child relationship'},
#   {'id': 3762, 'name': 'darkness'},
#   {'id': 4652, 'name': 'bath house'},
#   {'id': 2343, 'name': 'magic'},
#   {'id': 13153, 'name': 'spirit'},
#   {'id': 33465, 'name': 'parallel world'},
#   {'id': 155582, 'name': 'amusement park'},
#   {'id': 196509, 'name': 'youkai'},
#   {'id': 207695, 'name': 'japanese mythology'},
#   {'id': 210024, 'name': 'anime'}]}

# %%
test=response5.json()['results']

# %%
test[1]
# Out:
# {'adult': False,
#  'backdrop_path': '/kWYfW2Re0rUDE6IHhy4CRuKWeFr.jpg',
#  'genre_ids': [12, 14, 28],
#  'id': 121,
#  'original_language': 'en',
#  'original_title': 'The Lord of the Rings: The Two Towers',
#  'overview': "Frodo Baggins and the other members of the Fellowship continue on their sacred quest to destroy the One Ring--but on separate paths. Their destinies lie at two towers--Orthanc Tower in Isengard, where the corrupt wizard Saruman awaits, and Sauron's fortress at Barad-dur, deep within the dark lands of Mordor. Frodo and Sam are trekking to Mordor to destroy the One Ring of Power while Gimli, Legolas and Aragorn search for the orc-captured Merry and Pippin. All along, nefarious wizard Saruman awaits the Fellowship members at the Orthanc Tower in Isengard.",
#  'popularity': 21.7583,
#  'poster_path': '/5VTN0pR8gcqV3EPUHHfMGnJYN9L.jpg',
#  'release_date': '2002-12-18',
#  'title': 'The Lord of the Rings: The Two Towers',
#  'video': False,
#  'vote_average': 8.411,
# ...

# %%
# for movie_id in all_movie_ids1[:10]:  # Limit for testing
url = f"{Base_url}/movie/121"
params = {"api_key": API_key, "append_to_response": "keywords"}
responsef = requests.get(url, params=params)

# %%
responsef
# Out:
# <Response [200]>

# %%
responsef.json()
# Out:
# dict

# %%
test=responsef.json()

# %%
type(test)
# Out:
# dict

# %%
test.keys()
# Out:
# dict_keys(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id', 'imdb_id', 'origin_country', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count', 'keywords'])

# %%
keywords=[]
for i in range(0,5):
  keywords.append(test['keywords']['keywords'][i]['name'])

# %%
keywords
# Out:
# ['mission', 'army', 'based on novel or book', 'elves', 'dwarf']

# %%
test['keywords']
# Out:
# {'keywords': [{'id': 10364, 'name': 'mission'},
#   {'id': 6092, 'name': 'army'},
#   {'id': 818, 'name': 'based on novel or book'},
#   {'id': 603, 'name': 'elves'},
#   {'id': 604, 'name': 'dwarf'},
#   {'id': 2343, 'name': 'magic'},
#   {'id': 1523, 'name': 'obsession'},
#   {'id': 3930, 'name': 'bravery'},
#   {'id': 3098, 'name': 'castle'},
#   {'id': 5484, 'name': 'reincarnation'},
#   {'id': 9663, 'name': 'sequel'},
#   {'id': 14643, 'name': 'battle'},
#   {'id': 14707, 'name': 'brutality'},
#   {'id': 33788, 'name': 'guide'},
#   {'id': 156761, 'name': 'split personality'},
#   {'id': 162775, 'name': 'marsh'},
#   {'id': 170362, 'name': 'fantasy world'},
#   {'id': 177912, 'name': 'wizard'},
#   {'id': 189092, 'name': 'journey'},
#   {'id': 189093, 'name': 'ring'},
#   {'id': 209220, 'name': 'live action and animation'},
#   {'id': 209374, 'name': "hero's journey"},
#   {'id': 211227, 'name': 'high fantasy'},
#   {'id': 232697, 'name': 'wraith'},
# ...

# %%
test['keywords']=keywords

# %%
test['keywords']
# Out:
# ['mission', 'army', 'based on novel or book', 'elves', 'dwarf']

# %% [markdown]
# the end result

# %%
categories = [
    "popular",
    "top_rated",
    "now_playing",
    "upcoming"
]
all_movie_ids1 = set()
for category in categories:
    for page in range(1,56):
      url = f"{Base_url}/movie/{category}"
      params = {"api_key": API_key, "page": page, "append_to_response": "credits"}

      response5 = requests.get(url, params=params)
      data1 = response5.json()

      for movie in data1.get("results", []):
          all_movie_ids1.add(movie["id"])

# %%
len(all_movie_ids1)
# Out:
# 3147

# %%
list_of_movies=[]
for id in all_movie_ids1:
  url = f"{Base_url}/movie/{id}"
  params = {"api_key": API_key, "append_to_response": "keywords"}

  response = requests.get(url, params=params)

  if response.status_code == 200:
    data=response.json()

    keywords=[]
    all_keywords = data.get('keywords', {}).get('keywords', [])
    for j in range(0,min(5,len(all_keywords))):

    # for j in min(range(0,5),len(keywords)):
    #   if j <=len(test['keywords']['keywords']):
    #     break

      keywords.append(all_keywords[j]['name'])

      movie_data={
          'id':data['id'],
          'title':data['title'],
          'overview':data.get('overview',''),
          'genres':[g['name'] for g in data.get('genres', [])],
          'keywords':keywords,
          'adult':data.get('adult')
      }


    list_of_movies.append(movie_data)

# %%
len(list_of_movies)
# Out:
# 3147

# %%
df=pd.DataFrame(list_of_movies)

# %%
df.to_csv('movies.csv',index=False)

# %%
df.head()
# Out:
#        id                   title  \
# 0    8195                   Ronin
# 1  663558  New Gods: Nezha Reborn
# 2      11               Star Wars
# 3      12            Finding Nemo
# 4      13            Forrest Gump
#
#                                             overview  \
# 0  A briefcase with undisclosed contents – sought...
# 1  While living as an ordinary deliveryman and mo...
# 2  Princess Leia is captured and held hostage by ...
# 3  Nemo, an adventurous young clownfish, is unexp...
# 4  A man with a low IQ has accomplished great thi...
#
#                                  genres  \
# 0             [Action, Thriller, Crime]
# 1          [Animation, Fantasy, Action]
# 2  [Adventure, Action, Science Fiction]
# 3                   [Animation, Family]
# 4              [Comedy, Drama, Romance]
#
#                                             keywords  adult
# 0  [france, paris, france, arms deal, mercenary, ...  False
# 1  [based on novel or book, reincarnation, dragon...  False
# ...
